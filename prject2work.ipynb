# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\sumon23\Downloads\New folder\Book2.xlsx',sheetname = 'Sheet1')

# %%
df.head()
# Out:
#    Mass  Radius(cm)
# 0   2.0        16.6
# 1   3.2        26.9
# 2   5.0        42.0
# 3   7.5        63.0
# 4   8.7        73.1

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Mass', y = 'Radius(cm)',data = df)
sns.set_style('whitegrid')
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
sns.kdeplot(df['Mass'],shade = True)

# %%
sns.kdeplot(df['Radius(cm)'],shade = True)

# %%
sns.lmplot(x = 'Mass',y ='Radius(cm)',data = df,palette = 'seismic' )

# %%
sns.distplot(df['Mass'],kde = True,bins = 20)

# %%
sns.jointplot(x='Mass',y='Radius(cm)',data = df)

# %%
sns.jointplot(x='Mass',y = 'Radius(cm)',data = df,kind = 'kde')

# %%
df1 = pd.read_excel(r'C:\Users\sumon23\Downloads\New folder\Book3.xlsx',sheetname = 'Sheet1')

# %%
df1.head()
# Out:
#               Name  Mass
# 0       Cygnus x-1    16
# 1           SS-433    11
# 2  Nova Monocerote    11
# 3  Nova Persi 1992     5
# 4          IL Lupi     9

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Name', y = 'Mass',data = df1)
sns.set_style('whitegrid')
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
sns.stripplot(x = 'Name',y = 'Mass',jitter = True,data = df1)
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
sns.distplot(df1['Mass'])
